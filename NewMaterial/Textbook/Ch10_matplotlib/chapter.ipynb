# %% [markdown]
# # Chapter 10: Plotting with matplotlib
#
# Companion notebook. Read the written chapter at [chapter.html](https://natrask.github.io/engr1050-fall2026/NewMaterial/Textbook/Ch10_matplotlib/chapter.html). Solutions at the bottom.

# %% [markdown]
# ## Example 1: basic line plot

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(0, 2*np.pi, 100)
plt.figure(figsize=(6, 4))
plt.plot(x, np.sin(x))
plt.xlabel("x"); plt.ylabel("sin(x)"); plt.title("Sine over one period")
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# ## Example 2: markers and line styles

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(0, 10, 11)
plt.figure(figsize=(7, 4))
plt.plot(x, x, "o-", label="linear")
plt.plot(x, x**0.5 * 3, "s--", label="sqrt")
plt.plot(x, np.log(x + 1) * 3, "^:", label="log")
plt.xlabel("x"); plt.ylabel("y"); plt.legend(); plt.show()

# %% [markdown]
# ## Example 3: scatter

# %%
import numpy as np
import matplotlib.pyplot as plt
rng = np.random.default_rng(seed=0)
x = rng.standard_normal(200)
y = 0.5 * x + rng.standard_normal(200) * 0.5
plt.figure(figsize=(5, 5))
plt.scatter(x, y, s=20, alpha=0.6)
plt.xlabel("x"); plt.ylabel("y"); plt.title("Noisy linear relationship")
plt.show()

# %% [markdown]
# ## Example 4: histogram

# %%
import numpy as np
import matplotlib.pyplot as plt
rng = np.random.default_rng(seed=1)
data = rng.standard_normal(1000)
plt.figure(figsize=(7, 4))
plt.hist(data, bins=30, edgecolor="black")
plt.xlabel("value"); plt.ylabel("count"); plt.title("Standard normal samples")
plt.show()

# %% [markdown]
# ## Example 5: error bars

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.arange(1, 6)
y = np.array([2.1, 3.9, 6.2, 8.0, 9.9])
err = np.array([0.2, 0.3, 0.4, 0.3, 0.5])
plt.figure(figsize=(6, 4))
plt.errorbar(x, y, yerr=err, fmt="o", capsize=4)
plt.xlabel("x"); plt.ylabel("y"); plt.title("Data with measurement uncertainty")
plt.show()

# %% [markdown]
# ## Example 6: log-log convergence

# %%
import numpy as np
import matplotlib.pyplot as plt
n = np.array([10, 100, 1000, 10000, 100000])
err = 1.0 / np.sqrt(n)
plt.figure(figsize=(6, 4))
plt.loglog(n, err, "o-")
plt.xlabel("N"); plt.ylabel("error")
plt.title("Monte Carlo convergence")
plt.grid(True, which="both", alpha=0.3)
plt.show()

# %% [markdown]
# ## Example 7: subplots

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(0, 2*np.pi, 200)
fig, axes = plt.subplots(2, 2, figsize=(10, 6))
axes[0, 0].plot(x, np.sin(x));      axes[0, 0].set_title("sin")
axes[0, 1].plot(x, np.cos(x));      axes[0, 1].set_title("cos")
axes[1, 0].plot(x, np.tan(x));      axes[1, 0].set_title("tan"); axes[1, 0].set_ylim(-5, 5)
axes[1, 1].plot(x, np.sin(x)**2);   axes[1, 1].set_title("sin squared")
fig.tight_layout()
plt.show()

# %% [markdown]
# ## Example 8: twin y-axis

# %%
import numpy as np
import matplotlib.pyplot as plt
t = np.linspace(0, 10, 100)
temperature = 20 + 5 * np.sin(t)
pressure    = 100 + 10 * np.cos(t)
fig, ax1 = plt.subplots(figsize=(7, 4))
ax1.plot(t, temperature, "r-")
ax1.set_xlabel("time"); ax1.set_ylabel("temperature (C)", color="r")
ax1.tick_params(axis="y", labelcolor="r")
ax2 = ax1.twinx()
ax2.plot(t, pressure, "b-")
ax2.set_ylabel("pressure (kPa)", color="b")
ax2.tick_params(axis="y", labelcolor="b")
plt.show()

# %% [markdown]
# ## Example 9: annotation

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(0, 6, 100)
y = np.sin(x)
peak_x = np.pi / 2; peak_y = 1.0
plt.figure(figsize=(6, 4))
plt.plot(x, y)
plt.plot(peak_x, peak_y, "ro")
plt.annotate("peak", xy=(peak_x, peak_y),
             xytext=(peak_x + 1, peak_y + 0.1),
             arrowprops=dict(arrowstyle="->"))
plt.xlabel("x"); plt.ylabel("sin(x)"); plt.show()

# %% [markdown]
# ## Example 10: lab-quality figure

# %%
import numpy as np
import matplotlib.pyplot as plt
strain = np.linspace(0, 0.05, 50)
stress = 70000 * strain
stress[20:] = stress[19] + 100 * (strain[20:] - strain[19])
plt.figure(figsize=(7, 5))
plt.plot(strain, stress, "k-", lw=2, label="Al6XXX-T81")
plt.xlabel("strain"); plt.ylabel("stress (MPa)")
plt.title("Uniaxial tension of Al6XXX-T81 sheet (NIST data)")
plt.legend(loc="lower right"); plt.grid(True, alpha=0.3)
plt.tight_layout(); plt.savefig("stress_strain.png", dpi=150, bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Example 11: saving in a loop, closing each fig

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(0, 2*np.pi, 200)
for k in range(1, 4):
    fig, ax = plt.subplots(figsize=(6, 3))
    ax.plot(x, np.sin(k * x))
    ax.set_title(f"sin({k} x)")
    fig.savefig(f"sine_{k}.png", dpi=120, bbox_inches="tight")
    plt.close(fig)
print("done")

# %% [markdown]
# ## Example 12: 2D array as an image

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(-2, 2, 200); y = np.linspace(-2, 2, 200)
X, Y = np.meshgrid(x, y); Z = np.sin(X * X + Y * Y)
plt.figure(figsize=(5, 5))
plt.imshow(Z, extent=[x.min(), x.max(), y.min(), y.max()], origin="lower", cmap="viridis")
plt.colorbar(label="Z"); plt.xlabel("x"); plt.ylabel("y"); plt.title("sin(x^2 + y^2)")
plt.show()

# %% [markdown]
# ---
# ## Solutions

# %% [markdown]
# ### Problem 1: x squared from -3 to 3

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(-3, 3, 100)
plt.figure(figsize=(6, 4))
plt.plot(x, x**2)
plt.xlabel("x"); plt.ylabel("x^2"); plt.title("Quadratic")
plt.show()

# %% [markdown]
# ### Problem 2: linear vs log y-axis

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(0, 5, 100)
fig, axes = plt.subplots(1, 2, figsize=(10, 4))
axes[0].plot(x, np.exp(x)); axes[0].set_title("linear y")
axes[1].semilogy(x, np.exp(x)); axes[1].set_title("log y")
for ax in axes:
    ax.set_xlabel("x"); ax.set_ylabel("exp(x)")
plt.show()

# %% [markdown]
# ### Problem 3: distinct line styles

# %%
import numpy as np, matplotlib.pyplot as plt
x = np.linspace(0, 5, 100)
plt.plot(x, x, "-", label="x")
plt.plot(x, x**2, "--", label="x^2")
plt.plot(x, x**3, ":", label="x^3")
plt.legend(); plt.show()

# %% [markdown]
# ### Problem 4: histogram of normal samples

# %%
import numpy as np
import matplotlib.pyplot as plt
rng = np.random.default_rng(seed=42)
data = rng.standard_normal(1000)
plt.figure(figsize=(7, 4))
plt.hist(data, bins=50, edgecolor="black")
plt.xlabel("value"); plt.ylabel("count"); plt.title("1000 standard normal samples")
plt.show()

# %% [markdown]
# ### Problem 5: noisy line with overlaid true model

# %%
import numpy as np
import matplotlib.pyplot as plt
rng = np.random.default_rng(seed=0)
x = np.linspace(0, 10, 11)
y = 2 * x + 1 + rng.standard_normal(11)
plt.figure(figsize=(6, 4))
plt.scatter(x, y, label="data")
xs = np.linspace(0, 10, 100)
plt.plot(xs, 2 * xs + 1, "r-", label="y = 2x + 1")
plt.legend(); plt.xlabel("x"); plt.ylabel("y"); plt.show()
