# %% [markdown]
# # Lecture 16: Third lab, Designing the user interface for the helicopter
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/natrask/engr1050-fall2026/blob/main/NewMaterial/Lecture16/lec16.ipynb)

# %% [markdown]
# ## Overview
#
# For todays lecture, you will be working in groups of 2-3 and working in Thonny to push code onto the Picos again. Remember that **this Jupyter notebook is not meant to be run in Colab.**
#
# This is our last lab to prepare for the final construction of the helicopters. Today we will revisit our button-pushing/LED-flashing code from Lab 1, and use it to build up a user inferface for our helicopter. In the next and final lab, we will hook this up to the motor and use it to steer the helicopter.
#
# This is a **real-life size program**. So far you have really only done small bits of code. Today's lab is what it looks like to write software as part of an engineering team. Typically, a team lead will give you something with a number of `TODO` blocks that your job is to fill in to give the correct functionality. We will be simulating that kind of code-writing in this lab.
#
# Today's lab will be more independent than previous labs. In previous labs we have put together all of the classes and pieces, and so in principle you have written all the code you already need today and will just be doing copy and paste. Your job today will be to collectively with your group (and maybe with some help from Prof. Trask and Ben) complete the following tasks.
#
# **Design Requirements.**
#
# 1. Store a variable on the Pico that tracks the desired angle for the helicopter to hover at.
# 2. Take a potentiometer reading to check the current angle.
# 3. Set two buttons up to increase or decrease the desired angle.
# 4. Set one button up as a power button to turn the controller off/on.
# 5. A fourth button that turns the whole thing off.
# 6. Set one LED to turn off/on depending on whether the pendulum is within 5 degrees of the target angle.
# 7. Set a second LED to turn off/on depending on whether the controller is off/on.
#
# This has several moving pieces, but at the end of the day is just going to be a question of initializing `buttonClass` and `ledClass` attached to appropriate pins, and using if statements to use the correct logic. This might start to feel like a *big* code. The trick to pulling this off is to stay organized and break the big problem up into separate small parts, building everything piece by piece. If you feel stuck or overwhelmed - don't worry, Prof. Trask will be completing each `TODO` item on the projector to make sure you finish the lab with a working code.
#
# In the following sections you will find everything you need from previous labs so you don't need to look all over the place:
# - A skeleton of the program that you will flesh out
# - A reminder of how to flash an LED
# - A button and led class
# - The code from the last lab to calibrate the potentiometer.
#
# At the end, take a video of your setup functioning properly. Your video should show the lights indicating when the pendulum is on target, you using the buttons to adjust the target angle, and then you lighting up the new target lighting.

# %% [markdown]
# # Baseline code for you to fill in

# %% [markdown]
# ```python
# import math
# from machine import ADC, Pin
# import time
#
# print("Program is running")
#
# # Define the classes that you're going to need to use
# # TODO - copy and paste classes that you'll use here
#
# # Initialize buttons
# # TODO - make sure pins match your wiring
# quitButton = ButtonClass(pin_number=0)
# increaseButton = ButtonClass(pin_number=1)
# decreaseButton = ButtonClass(pin_number=2)
# toggleController = ButtonClass(pin_number=3)
#
# # Initialize the LEDs here, for example
# # TODO - make sure pins match your wiring
# ontargetLED = LEDClass(pin_number=16)
# poweronLED = LEDClass(pin_number=17)
#
# # Initialize potentiometer
# # TODO - make sure pins match your wiring
# potentiometer = ADC(Pin(26))
#
# # Set the initial state for the controller
# controllerAngle = 45   # target 45 degees to start
# controllerOn = False            # Start with controller turned off
#
# # TODO - Calibrate the raw voltage from the potentionmeter
# theta0 = 0
# theta90 = 0
# while True:
#     # Read potentiometer and convert reading to angle
#     currentTheta = 0
#     # TODO
#
#     # Capture button pressing events
#     quitPressed = quitButton.catchPress()
#     increasePressed = increaseButton.catchPress()
#     decreasePressed = decreaseButton.catchPress()
#     togglePressed = toggleController.catchPress()
#
#     # Capture potentiometer input
#     # TODO
#
#     # Add/subtract a degree to target if button pressed
#     # TODO
#
#     # Flip the Controller running variable if button is pressed (won't use this today)
#     controllerOn = False
#     # TODO
#
#     # Flip LED off/on depending on whether we are in range
#     # TODO
#
#     # Flip LED off/on depending on whether the controller is on
#     # (won't use this today, but this is whether we'll connect that motor in the final lab)
#     # TODO
#
#     # Power down if the quit button was pressed
#     if quitPressed == True:
#         print('Turning off...')
#         # Turn off the LED
#         break
#
#     # After executive all of the logic for the step, print out current state
#     print(f'Controller running = {controllerOn}. Theta = {currentTheta}, Target = {controllerAngle}')
#     time.sleep(0.1)  # Small delay
# ```

# %% [markdown]
# # Gather up the equipment you'll need

# %% [markdown]
# Before you get started, gather up these materials. Be sure to return them how you found them when you finish the exercise.
# - Grab one of the brown cardboard boxes, which will contain:
#     - A Pico breadboard kit
#     - A microUSB to USB cable
# - If your laptop doesn't have a USB port, you'll need to get a USB-to-USB-C converter.
# - You'll need one of the 3D-printed hovercraft assemblies.
# - You'll need a clamp to fix the hovercraft to the bottom of your workbench.
# - You will need a pile of female-to-female jumper cables. Remember that if you need longer ones you can stick two female-to-female cables on the end of a male-to-male cable.
# - Masking tape is floating around if you have loose connections.
#
# <div align="center">
#     <img src="../_shared/Images/lab1_image9.png" alt="Lab Setup" width="300">
# </div>

# %% [markdown]
# # Reminder: Flash an LED to check your connection

# %% [markdown]
# Here's a reminder on how to connect to the Pico. There is a small chance that the Pico's will be incompatible with your laptop - if you can't get a connection try another group members laptop; if that doesn't work raise your hand and we'll get you set up.
#
# The brown box consists of a Raspberry Pi Pico and a USB-to-micro USB cable.
#
# 1. Choose one group member's laptop that you will complete today's exercise with.
# 2. Before you connect the Pico to the laptop, there is something very annoying about Picos where they will screetch if you don't *ground* the beeping speaker. Take a *female-to-female* jumper cable and connect the `BEEP` pin to one of the ground (`GND`) pins. If you forget this, you will get a miserable noise.
#
# <div align="center">
#     <img src="../_shared/Images/lab1_image2.png" alt="Lab Setup" width="200">
# </div>
#
# 3. Connect the Pico to the laptop using the USB cable. You may need to use a USB-to-USB-C converter to do this if your laptop doesn't have a USB port (we'll have a box of converers available to you). Be gentle, but firm, when plugging it in. It should look like the following.
#
# <div align="center">
#     <img src="../_shared/Images/lab1_image1.png" alt="Lab Setup" width="200">
# </div>
#
# 4. In Thonny, you can specify whether you want to run the program on your PC or on the Pico through the USB cable. To do this select from the menu `Tools > Options...`. Select the `Interpreter` tab. Then, where it asks *Which kind of interpreter should Thonny use for running your code?* select `MicroPython (Raspberry Pi Pico)` and click `OK` to run on the chip. If you switch back to `Local Python 3` it will run on your PC again..
#
# <div align="center">
#     <img src="../_shared/Images/lab1_image3.png" alt="Lab Setup" width="600">
# </div>
#
# 5. At this point you are ready to run code! I've included the code block from the previous lab below that you can use to check that you're up and running. If you run and blink the on board LED, that means that you're in business. Remember that you may need to click the red stop button before you hit the green go button to make it run.

# %%
from machine import Pin
import time

# Initialize the onboard LED (connected to GPIO pin 25 on Pico)
led = Pin(25, Pin.OUT)

# Blink the LED continuously
while True:
    led.on()      # Turn LED on
    time.sleep(0.5)  # Wait 0.5 seconds
    led.off()     # Turn LED off
    time.sleep(0.5)  # Wait 0.5 seconds

# %% [markdown]
# 6. To run this code, click on the green arrow at the control bar in Thonny.
#
# <div align="center">
#     <img src="../_shared/Images/lab1_image4.png" alt="Lab Setup" width="600">
# </div>
#
# If the code is successfully running, you will see a blinking green LED on the Pico. This means you're in business!
#
# <div align="center">
#     <img src="../_shared/Images/lab1_image6.png" alt="Lab Setup" width="300">
# </div>

# %% [markdown]
# # Reminder: Wiring your potentiometer

# %% [markdown]
# 1. Grab one of the clamps and fix the base plate of the hovercraft to the bottom of the table. Make sure that the pendulum swings freely and doesn't bump into table legs or other obstructions. Once attached it should look like the following:
#
# <div align="center">
#     <img src="../_shared/Images/lab2_image1.png" alt="Lab Setup" width="300">
# </div>
#
# 2. Next we will need to wire up the potentiometer. There potentiometer has **three pins**. Two of the pins are used to flow current from a current source on the board (the 3.3 volt source pin `3V3`), through the potentiometer, and back out to `GND`. The other pin is used to capture a reading that we can use to track the angle of the pendulum.
#
# 3. **Wiring:**
# 3A. Connect one female-to-female wire to a `GND` pin on the board to the **left-most pin of the potentiometer**.
#     <div align="center">
#     <img src="../_shared/Images/lab2_image2.png" alt="Lab Setup" width="300">
#     </div>
# 3B. Connect one female-to-female wire to a `3V3` pin on the board to the **right-most pin of the potentiometer**. You now have power flowing through the potentiometer from the `3V3` source, through the device, and back into the Pico.
#     <div align="center">
#     <img src="../_shared/Images/lab2_image3.png" alt="Lab Setup" width="300">
#     </div>
# 3C. Connect one female-to-female wire to the `GP26` pin on the board to the **center-most pin of the potentiometer**. Unlike our previous lab, you can't use any old pin to take a reading - you need to use `GP26` specifically because it has something called `ADC` support, which has the hardware to convert analog signals into digital number readings.
#     <div align="center">
#     <img src="../_shared/Images/lab2_image4.png" alt="Lab Setup" width="300">
#     </div>

# %% [markdown]
# # Button and LED classes

# %% [markdown]
# ### Led class:

# %% [markdown]
# This is modified code from Lab 1 that provides a function to turn and LED off or on. You can copy and paste this into your Thonny to steer the LEDs.

# %%
from machine import Pin
import time

class LEDClass:
    def __init__(self, pin_number, initial_state=False):
        """
        Initialize LED class
        pin_number: GPIO pin number for the LED
        initial_state: True for on, False for off (default: False)
        """
        self.led = Pin(pin_number, Pin.OUT)
        self.state = initial_state
        
        # Set initial state
        if self.state:
            self.led.on()
        else:
            self.led.off()
    
    def toggle(self):
        """Toggle the LED state (on->off or off->on)"""
        if self.state:
            self.led.off()
            self.state = False
        else:
            self.led.on()
            self.state = True

# %% [markdown]
# ### Button class

# %% [markdown]
# I modified the button class from Lab 1. Now it returns True if a button was pressed and False otherwise. You can copy and paste this into your Thonny and use it to read buttons.

# %%
from machine import Pin
import time

# A class to catch when buttons are pressed
class ButtonClass:
    """
    A class to detect button press events on a Raspberry Pi Pico.
    
    This class handles button debouncing and edge detection, returning True
    only when a button press event occurs (transition from not pressed to pressed).
    """
    
    def __init__(self, pin_number):
        """
        Initialize the button class.
        
        Args:
            pin_number (int): GPIO pin number where the button is connected
            
        Note:
            Button should be wired with one side to the specified pin and 
            the other side to 3.3V. The internal pull-down resistor is enabled.
        """
        self.button = Pin(pin_number, Pin.IN, Pin.PULL_DOWN)
        
        # Store the button value at start to detect state changes
        self.oldbuttonstate = self.button.value() 

    def catchPress(self):
        """
        Check if a button press event has occurred.
        
        This method detects the rising edge of a button press (transition from 
        low to high) and returns True only once per press event.
        
        Returns:
            bool: True if a button press was detected, False otherwise
            
        Note:
            This method includes a small delay (0.01s) for basic debouncing.
            It should be called repeatedly in a loop to monitor button state.
        """
        # Check if any of the buttons have flipped their state        
        newbuttonstate = self.button.value()

        if self.oldbuttonstate == 0 and newbuttonstate == 1:
            # A button press was detected (rising edge)
            self.oldbuttonstate = newbuttonstate
            return True

        # Update the old state for next iteration
        self.oldbuttonstate = newbuttonstate
        
        # Small delay for debouncing
        time.sleep(0.01)
        return False

# %% [markdown]
# ### Example usage:

# %% [markdown]
# ```python
# from machine import Pin
# import time
#
# # Example usage for ButtonClass and LEDClass
# print("Button and LED Demo Starting...")
#
# # Create a button on pin 28 and an LED on pin 16
# button = ButtonClass(28)
# led = LEDClass(16, initial_state=False)  # Start with LED off
#
# print("Press the button to toggle the LED.")
#
# # Simple demo loop
# start_time = time.time()
# while True:
#     # Check if button was pressed
#     if button.catchPress():
#         led.toggle()  # Toggle LED state
#         print(f"Button pressed! LED is now {led.state}")
#
#     time.sleep(0.1)  # Small delay
# ```

# %% [markdown]
# # Potentiometer calibration

# %% [markdown]
# In the last lab we used the following to read in voltage from the potentiometer. You will need to calibrate `theta0` and `theta90`.

# %% [markdown]
# ```python
# # Initialize potentiometer
# potentiometer = ADC(Pin(26))
#
# # Set the following two numbers to match voltages to angles of 0 and 90 degrees
# theta0 = 34000
# theta90 = 9200
#
# while True:
#     # Read potentiometer and convert reading to angle
#     pot_value = potentiometer.read_u16() # Read the ADC value (0-65535)
#     theta_value = 90.0*(pot_value-theta0)/(theta90-theta0)
# ```

# %% [markdown]
# # Submit today's work #
# Today's assignment will be submitted by your group. You will submit **one video** capturing your finished interface correctly detecting whether the angle is on target and pushing buttons to lower and raise the target angle.
#
# Submit to Canvas using the following [link](https://canvas.upenn.edu/courses/1881448/assignments/14055878).
